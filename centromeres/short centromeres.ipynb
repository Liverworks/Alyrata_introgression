# %%
import pandas as pd

# %%
stas2 = pd.read_csv("short_read_centromere/all_jun_names", header=None)
#pd.read_csv("short_read_centromere/add_samp_list", header=None)
stas2
# Out:
#                 0
# 0         23180-5
# 1         23181-9
# 2         24052-2
# 3         24053-3
# 4         24054-1
# ..            ...
# 143    PU6-3_J6-4
# 144  TE8.1_J2-9.2
# 145   WS1-2_J2-23
# 146    TE4.3_J5-5
# 147   PU6-1_J6-44
#
# [148 rows x 1 columns]

# %%
stas2 = stas2.rename(columns={0: "ID"})

# %%
stas2["pAa"] = 0
stas2["pAL1"] = 0
stas2["pAge1"] = 0
stas2["pAge2"] = 0

# %%
with open("short_read_centromere/all_jun_names", "r") as samplist:
    for i in samplist.readlines():
        i = i.strip()
        name = "short_read_centromere/" + i + ".stats"
        print(i)
        stat_file = pd.read_csv(name, header=None, sep="\t")
        
        stas2.loc[stas2['ID'] == i, 'pAa'] = stat_file.iloc[0,2]
        stas2.loc[stas2['ID'] == i, 'pAL1'] = stat_file.iloc[1,2]
        stas2.loc[stas2['ID'] == i, 'pAge1'] = stat_file.iloc[2,2]
        stas2.loc[stas2['ID'] == i, 'pAge2'] = stat_file.iloc[3,2]
        #break
# Out:
# 23180-5
# 23181-9
# 24052-2
# 24053-3
# 24054-1
# 23180-7
# 23181-8
# MW0953765mix
# MW0953765mix-x
# MW0953767
# halxlyr1
# halxlyr2
# BAM12.1-1
# BAM12.2-1
# BAM12.3-1
# BAM12.4-1
# AL128V
# AL27AA
# AL56AC
# AL57CD
# AL57CB
# AL62-A-2
# AL104-A-2
# Al104-A-7
# AL08-A-C
# AL86-AC-14
# AL57CC
# AL86AC-17
# AL86AC7
# AL27AB-1
# AL62-B-12
# AL27AB-2
# AL05-B6
# AL104-A-3
# Niv1-1
# Niv2-1
# Niv3-1
# Mort1-1
# Mort2-1
# Mort3-1
# Mort4-1
# Penin1-1
# Penin2-1
# A.arNorv-1
# KST7-1
# KST2-1
# KST3-1
# KST4-1
# 23009-1
# 23008
# 23004-1
# 23005-1
# 23006-5
# 23006-1
# 23006-4
# 23003
# PU7mix_J2-20
# AL26B_J6-58
# AL26A_J9-20
# AL8B_J9-14
# AL85A_J9-11
# TE11-1_J5-8.2
# AL85A_J9-8
# AL85A_J9-9
# NT10.1_J6-30
# TE6-2_J1-24
# TE11-1_J5-6
# AL8B_J9-15
# PU5mix_J1-17
# NT16-1_J6-27
# NT1.2_J5-15
# NT18.1_J6-40
# AL56A_J6-62
# TE7-3_J1-10
# AL56A_J6-63
# TE10.2_J2-17
# AL56A_J6-62.2
# AL56A_J6-64
# AL56A_J6-63.2
# AL56A_J6-65
# AL56A_J6-65.2
# AL56B_J6-35
# AL56B_J6-20
# TE10.3_J2-15
# ...

# %%
stas.to_csv("jun24_shortreadcentromeres_prop.tsv", sep="\t", index=False)

# %%
stas2
# Out:
#                ID     pAa  pAL1   pAge1   pAge2
# 0         23180-5  567456    83  401449  162348
# 1         23181-9  546735   107  355749  159967
# 2         24052-2  512274    81  323295  206543
# 3         24053-3  463699    64  291679  181547
# 4         24054-1  462870    93  302710  176120
# ..            ...     ...   ...     ...     ...
# 143    PU6-3_J6-4  421713   152  464995  182093
# 144  TE8.1_J2-9.2  556122   115  527129  187094
# 145   WS1-2_J2-23  514576   139  551104  166532
# 146    TE4.3_J5-5  493449    97  487998  187299
# 147   PU6-1_J6-44  449190   167  420520  183126
#
# [148 rows x 5 columns]

# %%
stas = pd.concat([stas, stas2])

# %%
stas = pd.read_csv("all_stats_shortreadcentromeres_2.tsv", sep="\t")
stas.head()
# Out:
#         ID     pAa  pAL1   pAge1   pAge2
# 0  AL135_A  536536    60  428460  156790
# 1  AL135_B  531733    50  439939  186530
# 2  AL135_C  571383   131  466578  220537
# 3  AL135_D  474773    72  406863  177621
# 4  AL135_E  571176    90  497606  234437

# %%
species = pd.read_csv("short_read_centromere/list_with_species.tsv.csv", sep=",")
species.head()
# Out:
#         ID    Species_fin
# 0    al1_1      A. lyrata
# 1  AL135_A  A. kamchatica
# 2  AL135_B  A. kamchatica
# 3  AL135_C  A. kamchatica
# 4  AL135_D  A. kamchatica

# %%
stat_file
# Out:
#              0     1       2  3
# 0   pAa_contig  1969  695214  0
# 1  pAL1_contig  1958       7  0
# 2        page1  1859  788216  0
# 3        page2  1958   14921  0
# 4            *     0       0  0

# %%
stat_file.iloc[0,2]
# Out:
# 695214

# %%
stas.pAa[stas.ID == i] = stat_file.iloc[0,2]
# Out:
# /tmp/ipykernel_1394560/1999728119.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stas.pAa[stas.ID == i] = stat_file.iloc[0,2]

# %%
stas.to_csv("")
# Out:
#            ID     pAa  pAL1   pAge1   pAge2
# 0     AL135_A  536536    60  428460  156790
# 1     AL135_B  531733    50  439939  186530
# 2     AL135_C  571383   131  466578  220537
# 3     AL135_D  474773    72  406863  177621
# 4     AL135_E  571176    90  497606  234437
# ...       ...     ...   ...     ...     ...
# 1003   ex_825  900071    11  879673   15373
# 1004   ex_826  756321     5  796092   13172
# 1005   ex_827  725599     9  784155   12193
# 1006   ex_829  523904     4  683910   13038
# 1007   ex_831  594999     1  756199   13458
#
# [1008 rows x 5 columns]

# %%
stas.loc[stas['ID'] == i, 'pAa']
# Out:
# 208    0
# Name: pAa, dtype: int64

# %%
testhead = stas.head()

# %%
stat_file.iloc[0,2]
# Out:
# 695214

# %%
stas[stas.ID == i].loc[:,"pAa"]  = stat_file.iloc[0,2]
# Out:
# /tmp/ipykernel_1394560/2073164490.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stas[stas.ID == i].loc[:,"pAa"]  = stat_file.iloc[0,2]

# %%
stas[stas.ID == i]
# Out:
#        ID  pAa  pAL1  pAge1  pAge2
# 208  KN_2    0     0      0      0

# %%
testhead
# Out:
#         ID     pAa  pAL1   pAge1   pAge2
# 0  AL135_A  536536    60  428460  156790
# 1  AL135_B  531733    50  439939  186530
# 2  AL135_C  571383   131  466578  220537
# 3  AL135_D  474773    72  406863  177621
# 4  AL135_E  571176    90  497606  234437

# %%
import matplotlib.pyplot as plt 
  

testhead.iloc[:,[0,6,7,8,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas["tot"] = stas.pAa + stas.pAge1 + stas.pAge2 +  stas.pAL1

# %%
stas = stas2

# %%
stas["pAa_prop"] =  + stas.pAa / stas.tot
stas["pAL1_prop"] =  + stas.pAL1 / stas.tot
stas["pAge1_prop"] =  + stas.pAge1 / stas.tot
stas["pAge2_prop"] =  + stas.pAge2 / stas.tot

# %%
stas.iloc[0:18,[0,6,7,8,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas[stas.tot < 1000]
# Out:
#             ID  pAa  pAL1  pAge1  pAge2  tot  pAa_prop  pAL1_prop  pAge1_prop  \
# 208       KN_2    0     0      0      0    0       NaN        NaN         NaN
# 318  MW0079597   14     0      5      2   21  0.666667        0.0    0.238095
# 405  MW0158710   22     0     20      2   44  0.500000        0.0    0.454545
# 435   NT11_1_1  406     0    343     99  848  0.478774        0.0    0.404481
# 436   NT11_2_1   14     0      6      2   22  0.636364        0.0    0.272727
# 437   NT11_3_1   37     0     29      6   72  0.513889        0.0    0.402778
# 438   NT11_4_1   24     0     17      9   50  0.480000        0.0    0.340000
# 651  SRR519687    0     0      0      0    0       NaN        NaN         NaN
#
#      pAge2_prop
# 208         NaN
# 318    0.095238
# 405    0.045455
# 435    0.116745
# 436    0.090909
# 437    0.083333
# 438    0.180000
# 651         NaN

# %%
stas[stas.tot < 50000]
# Out:
#               ID    pAa  pAL1  pAge1  pAge2    tot  pAa_prop  pAL1_prop  \
# 18     BAM_1.1-1   5326     0   6659    798  12783  0.416647   0.000000
# 20    BAM_11.2-1  11638     0  17282   1079  29999  0.387946   0.000000
# 22     BAM_2.1-1   2434     1   3144    255   5834  0.417209   0.000171
# 26     BAM_8.1-1   3756     0   5311    220   9287  0.404436   0.000000
# 113    DUB_AA_14   4727     0   6451    526  11704  0.403879   0.000000
# 203   IRKU084812   4535     0   4856    679  10070  0.450348   0.000000
# 208         KN_2      0     0      0      0      0       NaN        NaN
# 318    MW0079597     14     0      5      2     21  0.666667   0.000000
# 398  MW0157478_3   3811     0   4206    817   8834  0.431401   0.000000
# 405    MW0158710     22     0     20      2     44  0.500000   0.000000
# 415    MW0374086  11389     0   9727   1777  22893  0.497488   0.000000
# 435     NT11_1_1    406     0    343     99    848  0.478774   0.000000
# ...

# %%
stas.iloc[0:18,0:5].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas.iloc[18:28,0:5].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas.iloc[28:46,[0,6,7,8,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas.iloc[28:48,0:5].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas.iloc[46:72,0:5].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas.iloc[46:69,[0,6,7,8,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas.iloc[69:89,[0,6,7,8,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas.iloc[89:110,0:5].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas.iloc[89:109,[0,6,7,8,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas.iloc[109:122,0:5].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas.iloc[109:122,[0,6,7,8,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas.iloc[162:187,[0,6,7,8,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas.iloc[187:187,0:5].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas.iloc[187:206,0:5].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas.iloc[206:211,[0,6,7,8,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas.iloc[211:222,0:5].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas.iloc[211:222,[0,6,7,8,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas.iloc[442:462,0:5].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas.iloc[996:,[0,6,7,8,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas.iloc[312:322]
# Out:
#                ID      pAa  pAL1   pAge1   pAge2      tot  pAa_prop  \
# 312  MW0079589_11   307076    93  291774   85964   684907  0.448347
# 313   MW0079589_8   316978    71  335130   74963   727142  0.435923
# 314   MW0079589_9   394839   943  390450  130324   916556  0.430785
# 315     MW0079591   664240    23  545067  185420  1394750  0.476243
# 316     MW0079595  1009334    36  750029  193565  1952964  0.516822
# 317     MW0079596   880419    51  644111  176220  1700801  0.517650
# 318     MW0079597       14     0       5       2       21  0.666667
# 319     MW0079604   608818    13  449461  163952  1222244  0.498115
# 320   MW0079604_5   426031    24  368121  170363   964539  0.441694
# 321     MW0079605   908489    48  860647   41388  1810572  0.501769
#
#      pAL1_prop  pAge1_prop  pAge2_prop
# 312   0.000136    0.426005    0.125512
# 313   0.000098    0.460887    0.103093
# 314   0.001029    0.425997    0.142189
# 315   0.000016    0.390799    0.132941
# ...

# %%
stas.iloc[996:1016,0:5].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas2 = stas.merge(species, on="ID", how='outer')

# %%
stas[stas.ID == 'ex553_191120_L1'].loc[:, "ID"]  = 'ex553_191120'
stas[stas.ID == 'ex553_191120'].loc[:, "pAa"]  = stas[stas.ID == 'ex553_191120'].pAa + stas[stas.ID == 'ex553_191120_L4'].pAa
# Out:
# /tmp/ipykernel_156453/3594847063.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stas[stas.ID == 'ex553_191120_L1'].loc[:, "ID"]  = 'ex553_191120'

# %%
stas[stas.ID == 'ex603_260121_L4']
# Out:
#                   ID     pAa  pAL1   pAge1  pAge2
# 927  ex603_260121_L4  126177     1  196954   2926

# %%
stas.loc[:, "pAa"][stas.loc[:, "ID"] == 'ex553_191120_L1']  += stas[stas.loc[:, "ID"] == 'ex553_191120_L4'].loc[:, "pAa"]
# Out:
# /tmp/ipykernel_156453/589764626.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stas.loc[:, "pAa"][stas.loc[:, "ID"] == 'ex553_191120_L1']  += stas[stas.loc[:, "ID"] == 'ex553_191120_L4'].loc[:, "pAa"]

# %%
stas[stas.ID == 'ex591_210121_L4']
# Out:
#                   ID     pAa  pAL1   pAge1  pAge2
# 919  ex591_210121_L4  183873     1  265713   3650

# %%
stas.loc[898, "pAge1"] += stas.loc[899, "pAge1"]
stas.loc[898, "pAa"] += stas.loc[899, "pAa"]
stas.loc[898, "pAge2"] += stas.loc[899, "pAge2"]
stas.loc[898, "pAL1"] += stas.loc[899, "pAL1"]
stas.loc[898, "ID"] = 'ex553_191120'

# %%
stas[stas.ID == 'ex553_191120_L4'].loc[:, "pAa"]
# Out:
# 899    448762
# Name: pAa, dtype: int64

# %%
stas.loc[918, "pAge1"] += stas.loc[919, "pAge1"]
stas.loc[918, "pAa"] += stas.loc[919, "pAa"]
stas.loc[918, "pAge2"] += stas.loc[919, "pAge2"]
stas.loc[918, "pAL1"] += stas.loc[919, "pAL1"]
stas.loc[918, "ID"] = 'ex591_210121'

# %%
stas.loc[926, "pAge1"] += stas.loc[927, "pAge1"]
stas.loc[926, "pAa"] += stas.loc[927, "pAa"]
stas.loc[926, "pAge2"] += stas.loc[927, "pAge2"]
stas.loc[926, "pAL1"] += stas.loc[927, "pAL1"]
stas.loc[926, "ID"] = 'ex603_260121'

# %%
stas = stas.drop([899, 919, 927])

# %%
stas
# Out:
#            ID     pAa  pAL1   pAge1   pAge2
# 0     AL135_A  536536    60  428460  156790
# 1     AL135_B  531733    50  439939  186530
# 2     AL135_C  571383   131  466578  220537
# 3     AL135_D  474773    72  406863  177621
# 4     AL135_E  571176    90  497606  234437
# ...       ...     ...   ...     ...     ...
# 1003   ex_825  900071    11  879673   15373
# 1004   ex_826  756321     5  796092   13172
# 1005   ex_827  725599     9  784155   12193
# 1006   ex_829  523904     4  683910   13038
# 1007   ex_831  594999     1  756199   13458
#
# [1005 rows x 5 columns]

# %%
stas2[stas2.Species_fin.isnull() ]
# Out:
# Empty DataFrame
# Columns: [ID, pAa, pAL1, pAge1, pAge2, Species_fin]
# Index: []

# %%
stas.merge(species, on="ID", how='outer')
# Out:
#            ID       pAa   pAL1     pAge1     pAge2    Species_fin
# 0     AL135_A  536536.0   60.0  428460.0  156790.0  A. kamchatica
# 1     AL135_B  531733.0   50.0  439939.0  186530.0  A. kamchatica
# 2     AL135_C  571383.0  131.0  466578.0  220537.0  A. kamchatica
# 3     AL135_D  474773.0   72.0  406863.0  177621.0  A. kamchatica
# 4     AL135_E  571176.0   90.0  497606.0  234437.0  A. kamchatica
# ...       ...       ...    ...       ...       ...            ...
# 1124  TE5.8-3       NaN    NaN       NaN       NaN      A. lyrata
# 1125    TE6.2       NaN    NaN       NaN       NaN      A. lyrata
# 1126    TE7.2       NaN    NaN       NaN       NaN      A. lyrata
# 1127  TE8.6-2       NaN    NaN       NaN       NaN      A. lyrata
# 1128  TE9.1.2       NaN    NaN       NaN       NaN      A. lyrata
#
# [1129 rows x 6 columns]

# %%
stas2[stas2.Species_fin == "A. kamchatica"]
# Out:
#                ID        pAa   pAL1     pAge1     pAge2    Species_fin
# 0         AL135_A   536536.0   60.0  428460.0  156790.0  A. kamchatica
# 1         AL135_B   531733.0   50.0  439939.0  186530.0  A. kamchatica
# 2         AL135_C   571383.0  131.0  466578.0  220537.0  A. kamchatica
# 3         AL135_D   474773.0   72.0  406863.0  177621.0  A. kamchatica
# 4         AL135_E   571176.0   90.0  497606.0  234437.0  A. kamchatica
# ..            ...        ...    ...       ...       ...            ...
# 604  SAMD00089941  1103719.0  224.0  602788.0  110040.0  A. kamchatica
# 605  SAMD00089942   880585.0  188.0  425295.0  100807.0  A. kamchatica
# 606  SAMD00089943   728589.0   44.0  530944.0   89225.0  A. kamchatica
# 607  SAMD00089944   659523.0   37.0  510360.0   91105.0  A. kamchatica
# 608  SAMD00089945   722669.0  157.0  487666.0   70030.0  A. kamchatica
#
# [139 rows x 6 columns]

# %%
stas2[stas2.Species_fin == "A. lyrata"]
# Out:
#               ID        pAa   pAL1     pAge1    pAge2 Species_fin
# 21    BAM_12.1-1   455394.0   39.0  504040.0  17734.0   A. lyrata
# 122   ERR3397904  1178407.0  284.0  697469.0   2726.0   A. lyrata
# 123   ERR3397905  1131926.0  383.0  703070.0   2200.0   A. lyrata
# 124   ERR3397906   619841.0   33.0  307960.0   1465.0   A. lyrata
# 125   ERR3397907  1132069.0   41.0  659682.0   2824.0   A. lyrata
# ...          ...        ...    ...       ...      ...         ...
# 1017      ex_825   900071.0   11.0  879673.0  15373.0   A. lyrata
# 1018      ex_826   756321.0    5.0  796092.0  13172.0   A. lyrata
# 1019      ex_827   725599.0    9.0  784155.0  12193.0   A. lyrata
# 1020      ex_829   523904.0    4.0  683910.0  13038.0   A. lyrata
# 1021      ex_831   594999.0    1.0  756199.0  13458.0   A. lyrata
#
# [709 rows x 6 columns]

# %%
stas2[(stas2.Species_fin != "A.arenosa") & (stas2.Species_fin != "A. arenosa") & (stas2.Species_fin != "A. kamchatica") & (stas2.Species_fin != "A. lyrata")]
# Out:
#              ID       pAa  pAL1     pAge1     pAge2           Species_fin
# 18    BAM_1.1-1    5326.0   0.0    6659.0     798.0  Neotorularia_humilis
# 19   BAM_10.3-1   71771.0   4.0   86906.0   10697.0  Neotorularia_humilis
# 20   BAM_11.2-1   11638.0   0.0   17282.0    1079.0  Neotorularia_humilis
# 22    BAM_2.1-1    2434.0   1.0    3144.0     255.0  Neotorularia_humilis
# 23    BAM_4.1-1   67924.0   4.0   98588.0    8234.0  Neotorularia_humilis
# ..          ...       ...   ...       ...       ...                   ...
# 884      a_H716  387839.0  12.0  262628.0  146318.0            A. halleri
# 885      a_H718  405155.0   7.0  118370.0  150195.0            A. halleri
# 886       a_H78  492493.0   3.0  175525.0  207616.0            A. halleri
# 887       a_H79  421292.0   3.0  134603.0  145436.0            A. halleri
# 888      a_H869  491088.0  50.0  328124.0  141907.0            A. halleri
#
# [152 rows x 6 columns]

# %%
stas2[(stas2.Species_fin != "A.arenosa") & (stas2.Species_fin != "A. arenosa") & (stas2.Species_fin != "A. kamchatica") & (stas2.Species_fin != "A. lyrata") & (stas2.Species_fin != "A. halleri") ]
# Out:
#              ID      pAa       pAL1    pAge1    pAge2           Species_fin
# 18    BAM_1.1-1   5326.0        0.0   6659.0    798.0  Neotorularia_humilis
# 19   BAM_10.3-1  71771.0        4.0  86906.0  10697.0  Neotorularia_humilis
# 20   BAM_11.2-1  11638.0        0.0  17282.0   1079.0  Neotorularia_humilis
# 22    BAM_2.1-1   2434.0        1.0   3144.0    255.0  Neotorularia_humilis
# 23    BAM_4.1-1  67924.0        4.0  98588.0   8234.0  Neotorularia_humilis
# ..          ...      ...        ...      ...      ...                   ...
# 665   SRR519660   2443.0  1383040.0      0.0      0.0           A. thaliana
# 666   SRR519684   1204.0   726165.0      0.0      0.0           A. thaliana
# 667   SRR519685   1639.0  1167514.0      0.0      0.0           A. thaliana
# 668   SRR519687      0.0        0.0      0.0      0.0           A. thaliana
# 669   SRR519714    653.0   290952.0      0.0      0.0           A. thaliana
#
# [130 rows x 6 columns]

# %%
stas2[(stas2.Species_fin != "A.arenosa") & (stas2.Species_fin != "A. arenosa") & (stas2.Species_fin != "A. kamchatica") & (stas2.Species_fin != "A. lyrata") & (stas2.Species_fin != "A. halleri") & (stas2.Species_fin != "A. thaliana") ]
# Out:
#              ID        pAa       pAL1    pAge1    pAge2           Species_fin
# 18    BAM_1.1-1     5326.0        0.0   6659.0    798.0  Neotorularia_humilis
# 19   BAM_10.3-1    71771.0        4.0  86906.0  10697.0  Neotorularia_humilis
# 20   BAM_11.2-1    11638.0        0.0  17282.0   1079.0  Neotorularia_humilis
# 22    BAM_2.1-1     2434.0        1.0   3144.0    255.0  Neotorularia_humilis
# 23    BAM_4.1-1    67924.0        4.0  98588.0   8234.0  Neotorularia_humilis
# ..          ...        ...        ...      ...      ...                   ...
# 454    NT11_3_1       37.0        0.0     29.0      6.0          neotorularia
# 455    NT11_4_1       24.0        0.0     17.0      9.0          neotorularia
# 456    NT11_5_1     1358.0        0.0    972.0    227.0          neotorularia
# 625  SRR3123760  2023067.0  1582019.0   1226.0    546.0            A. suecica
# 626  SRR3123767  1181461.0   822956.0    710.0    314.0            A. suecica
#
# [117 rows x 6 columns]

# %%
stas2[(stas2.Species_fin != "A.arenosa") & (stas2.Species_fin != "A. arenosa") & (stas2.Species_fin != "A. kamchatica") & (stas2.Species_fin != "A. lyrata") & (stas2.Species_fin != "A.lyrata") & (stas2.Species_fin != "A. halleri") & (stas2.Species_fin != "A. thaliana")  & (stas2.Species_fin != "Neotorularia_humilis")& (stas2.Species_fin != "neotorularia") &(stas2.Species_fin != "A.lyrata/A.arenosa") ]
# Out:
#               ID        pAa       pAL1      pAge1     pAge2  \
# 133   ERR3514856  1136178.0       26.0   657605.0    1855.0
# 134   ERR3514857  1229554.0        5.0   600954.0    4734.0
# 138   ERR3514861  1392633.0       48.0   881717.0    7848.0
# 139   ERR3514862  1812894.0       80.0  1037420.0     322.0
# 140   ERR3514863  1645082.0       77.0   975246.0   87872.0
# 144   ERR3514867  1341123.0       44.0     1353.0   31011.0
# 145   ERR3514868  1386692.0       36.0   240321.0     171.0
# 158   ERR3514881  1098552.0       10.0   282115.0   19934.0
# 159   ERR3514882  1403997.0       55.0   490352.0   14701.0
# 167   ERR3514890   713711.0       15.0   349250.0      71.0
# 168   ERR3514891   944940.0       38.0   403599.0     181.0
# 206        KAMCH  1171818.0      178.0   836849.0  370027.0
# 233    MW0079475   764434.0       22.0   714725.0  158939.0
# 273  MW0079552_6    20775.0      104.0    25484.0    4549.0
# 322    MW0079597       14.0        0.0        5.0       2.0
# ...

# %%
stas2[(stas2.ID == "ERR3514895") ]
# Out:
#              ID       pAa  pAL1     pAge1    pAge2        tot  pAa_prop  \
# 172  ERR3514895  961491.0   3.0  829303.0  21789.0  1812586.0  0.530453
#
#      pAL1_prop  pAge1_prop  pAge2_prop Species_fin
# 172   0.000002    0.457525    0.012021   A. lyrata

# %%
stas2.iloc[[1031, 1005, 221, 172, 517, 468, 714, 562, 890],[0,8,7,6,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas2.iloc[[1022, 1023],[0,8,7,6,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas2[stas2.Species_fin == "A. arenosa"]
# Out:
#              ID        pAa   pAL1    pAge1  pAge2        tot  pAa_prop  \
# 171  ERR3514894  1467657.0   53.0   1397.0  193.0  1469300.0  0.998882
# 610  SRR3111434   883413.0  235.0  16137.0  274.0   900059.0  0.981506
# 611  SRR3111435  1050813.0   49.0    125.0  403.0  1051390.0  0.999451
# 612  SRR3111436   771011.0   59.0  14527.0  308.0   785905.0  0.981049
# 613  SRR3111437   885835.0  228.0  17912.0  378.0   904353.0  0.979523
# 620  SRR3111444   958998.0   68.0  14238.0  254.0   973558.0  0.985045
# 621  SRR3111445   564716.0   23.0    562.0  217.0   565518.0  0.998582
# 622  SRR3111446  1207043.0   30.0  12138.0  422.0  1219633.0  0.989677
# 623  SRR3111447   965448.0  121.0   9103.0  293.0   974965.0  0.990239
#
#      pAL1_prop  pAge1_prop  pAge2_prop Species_fin
# 171   0.000036    0.000951    0.000131  A. arenosa
# 610   0.000261    0.017929    0.000304  A. arenosa
# 611   0.000047    0.000119    0.000383  A. arenosa
# 612   0.000075    0.018484    0.000392  A. arenosa
# ...

# %%
stas2.iloc[1024:1048,[0,8,7,6,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas2.iloc[[660, 625, 171, 877, 873, 6, 229, 517],[0,8,7,6,9]].plot(
    x = 'ID',
    kind = 'barh',
    stacked = True,
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas2[stas2.Species_fin == "A. halleri"].iloc[:,[0,8,7,6,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
species = pd.read_csv("short_read_centromere/lyrata_pops.csv", sep="\t")
species.head()
# Out:
#            ID population
# 0       al1_1      CS_4n
# 1       al2_1      CS_4n
# 2       al3_1      CS_4n
# 3       al4_1      CS_4n
# 4  BAM_12.1-1      ES_2n

# %%
stas3 = stas2.merge(species, on="ID", how='left')

# %%
stas3[stas3.population == "CS_4n"].iloc[:,[0,8,7,6,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas3[stas3.population == "CS_2n"].iloc[:,[0,8,7,6,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas3[stas3.population == "ES_2n"].iloc[:,[0,8,7,6,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas3[stas3.population == "ES_2n"].iloc[:20,[0,8,7,6,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas3[(stas3.population != "ES_2n") & (stas3.population.isnull() == False)& (stas3.population != "CS_2n") & (stas3.population != "CS_4n") & (stas3.population != "UKScandinavia_2n") & (stas3.population != "Austria_4n")& (stas3.population != "Austria_2n")& (stas3.population != "Germany_2n")& (stas3.population != "CESiberia_4n")&(stas3.population != "NA_2n")&(stas3.population != "EE_4n")&(stas3.population != "EE_2n")&(stas3.population != "WS_2n")& (stas3.population != "SU_2n")&(stas3.population != "IS_2n")&(stas3.population != "SES_2n")&(stas3.population != "kamchatica")& (stas3.population != "exclude")&(stas3.population != "CESiberia")&(stas3.population != "CESiberia_2n")& (stas3.population != "selfer")]
# Out:
#               ID        pAa   pAL1      pAge1     pAge2        tot  pAa_prop  \
# 224    MW0079466   707663.0   24.0   742456.0  105595.0  1555738.0  0.454873
# 618   SRR3111442   498951.0    3.0   425255.0    8377.0   932586.0  0.535019
# 619   SRR3111443   571106.0   22.0   612318.0    9327.0  1192773.0  0.478805
# 624   SRR3111448   770214.0   15.0   627858.0   15706.0  1413793.0  0.544786
# 627   SRR5124974  1084323.0   18.0  1027673.0  141232.0  2253246.0  0.481227
# 633   SRR5124980  1157991.0   23.0  1110917.0  108498.0  2377429.0  0.487077
# 646   SRR5124993   658225.0    3.0   645591.0   66030.0  1369849.0  0.480509
# 654   SRR5125001  1068146.0   36.0  1028141.0  134240.0  2230563.0  0.478868
# 855     WS_1.1-1   331339.0   15.0   390262.0  102853.0   824469.0  0.401882
# 856     WS_1.1-2   297362.0   16.0   316062.0   86897.0   700337.0  0.424598
# 857     WS_1.2-1   284850.0   26.0   316792.0   71201.0   672869.0  0.423336
# ...

# %%
stas3[stas3.population == "UKScandinavia_2n"].iloc[:,[0,8,7,6,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas3[stas3.population == "Austria_4n"].iloc[:,[0,8,7,6,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas3[stas3.population == "Austria_2n"].iloc[:20,[0,8,7,6,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas3[(stas3.population == "EE_4n") | (stas3.population == "EE_4N")].iloc[:,[0,8,7,6,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas3[stas3.population == "Germany_2n"].iloc[:,[0,8,7,6,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas3[stas3.population == "CESiberia_2n"].iloc[:20,[0,8,7,6,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas3[stas3.population == "selfer"].iloc[:20,[0,8,7,6,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas3[stas3.population == "CESiberia_4n"].iloc[:20,[0,8,7,6,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas3[stas3.population == "CESiberia"].iloc[:20,[0,8,7,6,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas3[stas3.population == "NA_2n"].iloc[:20,[0,8,7,6,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas3[(stas3.population == "exclude") |(stas3.population == "freak")  ].iloc[:20,[0,8,7,6,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas3[stas3.population == "SES_2n"].iloc[:,[0,8,7,6,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas3[stas3.population == "IS_2n"].iloc[:,[0,8,7,6,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas3[stas3.population == "SU_2n"].iloc[:,[0,8,7,6,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas3[stas3.population == "WS_2n"].iloc[:,[0,8,7,6,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas3[(stas3.population == "EE_2n")].iloc[:,[0,8,7,6,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas3[stas3.population == "Chechia_2n"].iloc[:,[0,8,7,6,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas3[stas3.population == "Chechia_4n"].iloc[:,[0,8,7,6,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas3[stas3.population == "Karelia_2n"].iloc[:,[0,8,7,6,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas3[stas3.population == "WS_2n"].iloc[87:110,[0,8,7,6,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas3[stas3.population == "ES_2n"].iloc[65:80,[0,8,7,6,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas3[(stas3.population.isnull() == True) & (stas3.Species_fin == "A. lyrata")].iloc[175:190,0:5].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas.iloc[0:18,[0,6,7,8,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas.iloc[12:16,[0,6,7,8,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas.iloc[16:36,[0,6,7,8,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas.iloc[34:56,[0,6,7,8,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas.iloc[55:75,[0,6,7,8,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas.iloc[0:36,[0,1,2,3,4]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas.iloc[75:95,[0,6,7,8,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas.iloc[95:115,[0,6,7,8,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas.iloc[115:135,[0,6,7,8,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>

# %%
stas.iloc[135:155,[0,6,7,8,9]].plot( 
    x = 'ID', 
    kind = 'barh', 
    stacked = True, 
    mark_right = True)
# Out:
# <AxesSubplot: ylabel='ID'>
