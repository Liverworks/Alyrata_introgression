# %%
import pandas as pd

# %%
strands = pd.read_csv("array_strands.tsv", sep="\t")
strands.head()
# Out:
#       ID  Positive_1  Negative_1  Positive_2  Negative_2  Positive_3  \
# 0    Ped       13482        3506       19061           0        1174
# 1  Ceb_c       10463       10328        2541       13214        1204
# 2  Ceb_d       13884        2800       13222          72        1296
# 3   AL08        9951        2308       12171           0       12935
# 4   AL27         333       13505       10883           0       13500
#
#    Negative_3  Positive_4  Negative_4  Positive_5  Negative_5  Positive_6  \
# 0       14556        9665        1508       11130        1145       17989
# 1       29215        6959           0       12290        5858       19838
# 2       14032       14040         820        6310       16874       16246
# 3          29           0       13177        9978         101       10230
# 4           1           0       13567       10607           0        4474
#
#    Negative_6  Positive_7  Negative_7  Positive_8  Negative_8
# ...

# %%
fig = plt.figure(figsize=(10, 8))

n_samp=21
n = 0
for n in range(n_samp):
    for i in range(8):
        ax = fig.add_subplot(n_samp,8,n*8+i+1)
        ax.pie(strands.iloc[n, [2*i+1,2*i+2]])

# %%
import matplotlib.pyplot as plt

# %%
plt.pie(strands.iloc[0, [1,2]], labels=["positive", 'negative'])
plt.legend()
